# %% [markdown]
# # DEMO 3.4: **Naive Bayes**
# <u>Nội dung</u>:
# https://scikit-learn.org/stable/modules/naive_bayes.html
# 1. Gaussian NB
# 2. Multinomial NB
#
# <u>Cập nhật</u>: **04/2023**

# %% [markdown]
# ---
# ### **MÔI TRƯỜNG TRIỂN KHAI ỨNG DỤNG**
# ---

# %%
## Môi trường lập trình
from google.colab import drive
drive.mount("/content/gdrive")
folder = '/content/gdrive/My Drive/Colab Notebooks/ML/Supervised Learning'
# Out:
# Mounted at /content/gdrive

# %%
## Thư viện
import joblib                as jlb
import matplotlib.pyplot     as plt
import numpy                 as np
import pandas                as pd
import seaborn               as sbn

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes     import GaussianNB, BernoulliNB, MultinomialNB

# %% [markdown]
# ---
# ## 1. **Gaussian NB**
# ---

# %%
## Tập tin dữ liệu IRIS
data = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/ML/Supervised Learning/Data/Iris.xls')

# %%
X = data.drop('iris', axis = 1)
X.head()

## Biến target: iris
y = data.iris

print(pd.concat([X, y], axis = 1).head())

## Chia tập dữ liệu thành training, test sets theo tỷ lệ 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 1)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth         iris
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
##------------------------------------------------------------------------------
## Huấn luyện mô hình Gaussian NB
##------------------------------------------------------------------------------
Gmodel = GaussianNB()

##Fit
Gmodel.fit(X_train, y_train)

##Predict
y_pred = Gmodel.predict(X_test)

##Accuracy
print('Accuracy:', Gmodel.score(X_test, y_test))
# Out:
# Accuracy: 0.9666666666666667

# %%
## Khai thác mô hình Gaussian NB đã được huấn luyện để đoán (Test set)
tiep = 'C'
while (tiep.upper() == 'C'):
    idx    = int(eval(input(f'Nhập chỉ số dòng từ 0 đến {X_test.shape[0]}: ')))
    idx    = idx % X_test.shape[0]
    X_new  = X_test[idx:idx + 1]
    y_pred = Gmodel.predict(X_new)
    print('Mẫu', X_new.to_string(), '    được dự đoán là', y_pred)
    tiep = input('Tiếp tục (C/K) ? ')
# Out:
# Nhập chỉ số dòng từ 0 đến 30: 5
# Mẫu     sepallength  sepalwidth  petallength  petalwidth
# 56          6.3         3.3          4.7         1.6     được dự đoán là ['Iris-versicolor']
# Tiếp tục (C/K) ? c
# Nhập chỉ số dòng từ 0 đến 30: 2
# Mẫu     sepallength  sepalwidth  petallength  petalwidth
# 75          6.6         3.0          4.4         1.4     được dự đoán là ['Iris-versicolor']
# Tiếp tục (C/K) ? k

# %% [markdown]
# ---
# ## 2. **Multinomial NB**
# ---

# %%
## Tập tin dữ liệu Social_Network_Ads
data = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/ML/Supervised Learning/Data/Social_Network_Ads.csv')

# %%
## Các features: Gender, Age, EstimatedSalary
X = data.drop(['User ID', 'EstimatedSalary_K', 'Purchased'], axis = 1)

## Chuyển Gender thành kiểu Numerical
sex = {'Male':1, 'Female':0}
X['Male'] = [sex[i] for i in data.Gender]
X         = X.drop(['Gender'], axis = 1)

## Biến target: Purchased
y = data.Purchased

print(pd.concat([X, y], axis = 1).head())

## Chia tập dữ liệu thành training, test sets theo tỷ lệ 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 1)
# Out:
#    Age  EstimatedSalary  Male  Purchased
# 0   19            19000     1          0
# 1   35            20000     1          0
# 2   26            43000     0          0
# 3   27            57000     0          0
# 4   19            76000     1          0

# %%
##------------------------------------------------------------------------------
## Huấn luyện mô hình Multinomial NB
##------------------------------------------------------------------------------
Mmodel = MultinomialNB()

#Fit
Mmodel.fit(X_train, y_train)

##Predict
y_pred = Mmodel.predict(X_test)

##Accuracy
print('Accuracy:', Mmodel.score(X_test, y_test))
# Out:
# Accuracy: 0.55

# %%
## Khai thác mô hình Multinomial NB đã được huấn luyện để đoán (Test set)
labels = np.array(['KHÔNG mua', 'MUA'])

tiep = 'C'
while (tiep.upper() == 'C'):
    idx    = int(eval(input(f'Nhập chỉ số dòng từ 0 đến {X_test.shape[0]}: ')))
    idx    = idx % X_test.shape[0]
    X_new  = X_test[idx:idx + 1]
    y_pred = Mmodel.predict(X_new)
    print('Mẫu', X_new.to_string(), '      được dự đoán là', labels[y_pred])
    tiep = input('Tiếp tục (C/K) ? ')
# Out:
# Nhập chỉ số dòng từ 0 đến 80: 6
# Mẫu      Age  EstimatedSalary  Male
# 197   20            36000     0       được dự đoán là ['KHÔNG mua']
# Tiếp tục (C/K) ? k
